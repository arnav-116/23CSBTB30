# %% [markdown]
# <a href="https://colab.research.google.com/github/arnav-116/23CSBTB30/blob/main/Assignment_2(AIML).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from scipy import stats as s

# %%
d=pd.read_excel("/content/arnav aiml.xlsx")
d
# Out:
#      SID       S.Name Course  Age  Contact No.
# 0   2111      Ronaldo    CSE   19   9849686462
# 1   2112        Messi   AIML   19   9876453299
# 2   2113       Neymar   AIML   19   9963250072
# 3   2114        Kroos    CSE   19   7799886699
# 4   2115     DeBruyne    CSE   19   8143814266
# 5   2116        Pirlo    CSE   19   9235225677
# 6   2117     R.Carlos    CSC   19   9392646488
# 7   2118        Ramos    CSC   19   9963230073
# 8   2119      Maldini   AIML   19   6340809843
# 9   2120         Cafu    CSE   19   9898779922
# 10  2121       Buffon    CSC   19   1236549870
# 11  2122       Modric   AIML   19   9912993499
# 12  2123       Cruyff   AIML   19   8876768876
# 13  2124  Beckenbauer    CSE   19   9899901234
# 14  2125     Casillas    CSE   19   9849676831
# 15  2126  Ibrahimovic    CSE   19   8181323244
# 16  2127      Gerrard    CSE   19   7799223377
# 17  2128       Hazard   AIML   19   8543627109
# 18  2129         Bale   AIML   19   9393459962
# ...

# %%
d=pd.read_csv('/content/heart.csv')
d
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
d=pd.read_csv('/content/games_dataset.csv')
d
# Out:
#                                     Game Name       Genre         Platform  \
# 0                   Sekiro: Shadows Die Twice      Sports  Nintendo Switch
# 1                                     Control      Puzzle  Nintendo Switch
# 2                                    Among Us    Strategy  Nintendo Switch
# 3                Call of Duty: Modern Warfare     Stealth      PlayStation
# 4                           League of Legends  Simulation               PC
# ...                                       ...         ...              ...
# 4995  The Legend of Zelda: Breath of the Wild      Sports               PC
# 4996                Assassin's Creed Valhalla     Stealth           Mobile
# 4997             Fall Guys: Ultimate Knockout      Sports           Mobile
# 4998                            Borderlands 3  Platformer             Xbox
# 4999         Counter-Strike: Global Offensive      Action      PlayStation
#
#       Release Year  User Rating
# 0             2014     9.654719
# ...
